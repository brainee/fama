# %%
import numpy as np
import pandas as pd
import scipy
import math
import statsmodels
import datetime
import time

# %%
dp = get_fundamentals(
        query(fundamentals.eod_derivative_indicator.market_cap,fundamentals.financial_indicator.book_value_per_share)
        ,'2010-11-01', '60m')

market = all_instruments()
print("market['order_book_id']=",len(market['order_book_id']),market['order_book_id']);

price_data = get_price(list(market['order_book_id']),start_date='2005-11-01', end_date='2010-10-30',frequency='1d',fields='ClosingPx')
# Out:
# market['order_book_id']= 11267 0        399551.XSHE
# 1             AU1008
# 2             FU1308
# 3        000602.XSHE
# 4             TA0904
# 5             TA1103
# 6             AL0311
# 7              C0605
# 8        801121.INDX
# 9        150216.XSHE
# 10       603683.XSHG
# 11            JD1510
# 12       600048.XSHG
# 13       511830.XSHG
# 14            ZC1702
# 15            AL1410
# 16            SN1610
# 17       002816.XSHE
# 18       160323.XSHE
# 19            CU1502
# 20       000635.XSHE
# 21       399393.XSHE
# 22       150301.XSHE
# 23       002606.XSHE
# 24       600016.XSHG
# 25       603029.XSHG
# 26             C0707
# 27       600337.XSHG
# 28       150118.XSHE
# 29            SF1606
#             ...
# 11237    600110.XSHG
# 11238         BB1611
# 11239         AL1212
# 11240          SF888
# 11241    600180.XSHG
# 11242    H11166.XSHG
# 11243    002689.XSHE
# 11244    600299.XSHG
# 11245         OI1609
# 11246         AL0401
# 11247    500018.XSHG
# ...

# %%
price_data
# Out:
#             399551.XSHE  AU1008  FU1308  000602.XSHE  TA0904  TA1103  AL0311  \
# 2005-11-01          NaN     NaN     NaN       2.6212     NaN     NaN     NaN
# 2005-11-02          NaN     NaN     NaN       2.6212     NaN     NaN     NaN
# 2005-11-03          NaN     NaN     NaN       2.6212     NaN     NaN     NaN
# 2005-11-04          NaN     NaN     NaN       2.6212     NaN     NaN     NaN
# 2005-11-07          NaN     NaN     NaN       2.6212     NaN     NaN     NaN
# 2005-11-08          NaN     NaN     NaN       2.6212     NaN     NaN     NaN
# 2005-11-09          NaN     NaN     NaN       2.6212     NaN     NaN     NaN
# 2005-11-10          NaN     NaN     NaN       2.6212     NaN     NaN     NaN
# 2005-11-11          NaN     NaN     NaN       2.6212     NaN     NaN     NaN
# 2005-11-14          NaN     NaN     NaN       2.5027     NaN     NaN     NaN
# 2005-11-15          NaN     NaN     NaN       2.4102     NaN     NaN     NaN
# ...

# %%
index_date = dp['book_value_per_share'].index
print("index_date",index_date)
stocks = dp['book_value_per_share'].columns
# print('stocks',stocks)
stocks
# Out:
# index_date DatetimeIndex(['2010-11-01', '2010-09-30', '2010-08-30', '2010-07-30',
#                '2010-06-30', '2010-05-28', '2010-04-28', '2010-03-26',
#                '2010-02-26', '2010-01-26', '2009-12-25', '2009-11-25',
#                '2009-10-23', '2009-09-23', '2009-08-21', '2009-07-21',
#                '2009-06-19', '2009-05-19', '2009-04-17', '2009-03-17',
#                '2009-02-17', '2009-01-16', '2008-12-16', '2008-11-14',
#                '2008-10-14', '2008-09-12', '2008-08-12', '2008-07-11',
#                '2008-06-11', '2008-05-09', '2008-04-09', '2008-03-07',
#                '2008-02-05', '2008-01-04', '2007-12-04', '2007-11-02',
#                '2007-09-28', '2007-08-28', '2007-07-27', '2007-06-27',
#                '2007-05-25', '2007-04-25', '2007-03-23', '2007-02-16',
#                '2007-01-16', '2006-12-15', '2006-11-15', '2006-10-13',
#                '2006-09-13', '2006-08-11', '2006-07-11', '2006-06-09',
# ...

# %%
df_book_value=dp['book_value_per_share']
df_market_cap=dp['market_cap']
df_book_value
# Out:
#            002334.XSHE 000683.XSHE 002326.XSHE 600841.XSHG 000541.XSHE  \
# 2010-11-01        7.93         2.7        6.49        4.07        2.72
# 2010-09-30       14.78        2.68         6.4        3.99        2.58
# 2010-08-30       14.78        2.68         6.4        3.99        2.58
# 2010-07-30       14.34        4.01        6.56        4.01        2.75
# 2010-06-30       14.34        4.01        6.56        4.01        2.75
# 2010-05-28       14.34        4.01        6.56        4.01        2.75
# 2010-04-28       14.34        3.98        6.56        4.01        2.64
# 2010-03-26        4.17        2.48        6.47        3.95        2.64
# 2010-02-26        3.43        2.48        2.24        3.86        2.64
# 2010-01-26        3.43        2.48        2.24        3.86        2.64
# 2009-12-25         NaN        2.48        2.24        3.86        2.64
# 2009-11-25         NaN        2.48         NaN        3.86        2.64
# ...

# %%
df_book_value.to_csv("data/book_value_per_share.csv")
df_market_cap.to_csv("data/market_cap.csv")
price_data.to_csv("data/price_data.csv")

# %%
df=df_book_value.iloc[-2:, :3]
# df.index=[0,1]
# df.columns=[0,1,2]
t=type(np.nan)
print("t",t)
df
# where_are_NaNs = np.isnan(df)
# where_are_NaNs
# Out:
# t <class 'float'>
#            002290.XSHE 600595.XSHG 002378.XSHE
# 2005-11-04         NaN      3.6706         NaN
# 2005-09-30         NaN      3.6175         NaN

# %%
e1=df.iloc[0,0]
print("e1",e1,type(e1))

e2=df.iloc[0,2]
print("e2",e2,type(e2))
# df.dropna(how="any")
# df.fillna(5.0)
# df[math.isnan(df)]=0

# where_are_NaNs=np.isnan(df)
# where_are_NaNs
# Out:
# e1 nan <class 'float'>
# e2 nan <class 'float'>

# %%
df_book_value=df_book_value.fillna(0)
df_book_value
# Out:
#             002290.XSHE  600595.XSHG  002378.XSHE  600589.XSHG  002270.XSHE  \
# 2010-11-01         5.98       2.3575         2.77       2.9900       3.7500
# 2010-09-30         5.83       2.3900         2.84       2.9340       3.6900
# 2010-08-30         5.83       2.3900         2.84       2.9340       3.6900
# 2010-07-30         5.62       2.3900         2.75       2.8800       3.6900
# 2010-06-30         5.62       2.3800         2.75       2.8800       3.8400
# 2010-05-28         5.62       2.3800         2.75       2.8800       3.8400
# 2010-04-28         5.62       2.3800         2.75       2.8800       3.8400
# 2010-03-26        10.00       4.0400         0.00       2.8200       3.7900
# 2010-02-26        10.00       4.0400         0.00       2.8200       3.7900
# 2010-01-26        10.00       3.9400         0.00       2.8200       3.7100
# 2009-12-25         9.79       3.9400         0.00       2.8200       3.7100
# ...

# %%
df_market_cap=df_market_cap.fillna(0)
df_market_cap
# Out:
#              002290.XSHE   600595.XSHG   002378.XSHE   600589.XSHG  \
# 2010-11-01  5.113310e+09  1.947317e+10  2.089683e+10  5.253103e+09
# 2010-09-30  4.058446e+09  1.601863e+10  1.387840e+10  4.735615e+09
# 2010-08-30  4.770216e+09  1.481191e+10  1.327034e+10  4.326439e+09
# 2010-07-30  4.413578e+09  1.497754e+10  1.130912e+10  4.476871e+09
# 2010-06-30  3.745447e+09  1.317929e+10  1.127915e+10  4.073712e+09
# 2010-05-28  4.198392e+09  1.580568e+10  1.380989e+10  4.176006e+09
# 2010-04-28  4.517410e+09  1.556907e+10  1.545851e+10  4.861978e+09
# 2010-03-26  5.319468e+09  1.651552e+10  0.000000e+00  4.645356e+09
# 2010-02-26  5.649688e+09  1.615534e+10  0.000000e+00  4.518992e+09
# 2010-01-26  5.212460e+09  1.480797e+10  0.000000e+00  4.410681e+09
# 2009-12-25  3.807980e+09  1.616192e+10  0.000000e+00  4.488906e+09
# 2009-11-25  4.005276e+09  1.503144e+10  0.000000e+00  4.711546e+09
# 2009-10-23  3.477760e+09  1.513002e+10  0.000000e+00  4.218127e+09
# ...

# %%
price_data=price_data.fillna(0)
price_data
# Out:
#             300039.XSHE  V1001  000055.XSHG        P99  TA0903  SR0809  \
# 2005-11-01       0.0000    0.0        0.000     0.0000     0.0     0.0
# 2005-11-02       0.0000    0.0        0.000     0.0000     0.0     0.0
# 2005-11-03       0.0000    0.0        0.000     0.0000     0.0     0.0
# 2005-11-04       0.0000    0.0        0.000     0.0000     0.0     0.0
# 2005-11-07       0.0000    0.0        0.000     0.0000     0.0     0.0
# 2005-11-08       0.0000    0.0        0.000     0.0000     0.0     0.0
# 2005-11-09       0.0000    0.0        0.000     0.0000     0.0     0.0
# 2005-11-10       0.0000    0.0        0.000     0.0000     0.0     0.0
# 2005-11-11       0.0000    0.0        0.000     0.0000     0.0     0.0
# 2005-11-14       0.0000    0.0        0.000     0.0000     0.0     0.0
# 2005-11-15       0.0000    0.0        0.000     0.0000     0.0     0.0
# 2005-11-16       0.0000    0.0        0.000     0.0000     0.0     0.0
# ...

# %%
print("index_date:{}".format(index_date,333))
# Out:
# index_date:DatetimeIndex(['2010-11-01', '2010-09-30', '2010-08-30', '2010-07-30',
#                '2010-06-30', '2010-05-28', '2010-04-28', '2010-03-26',
#                '2010-02-26', '2010-01-26', '2009-12-25', '2009-11-25',
#                '2009-10-23', '2009-09-23', '2009-08-21', '2009-07-21',
#                '2009-06-19', '2009-05-19', '2009-04-17', '2009-03-17',
#                '2009-02-17', '2009-01-16', '2008-12-16', '2008-11-14',
#                '2008-10-14', '2008-09-12', '2008-08-12', '2008-07-11',
#                '2008-06-11', '2008-05-09', '2008-04-09', '2008-03-07',
#                '2008-02-05', '2008-01-04', '2007-12-04', '2007-11-02',
#                '2007-09-28', '2007-08-28', '2007-07-27', '2007-06-27',
#                '2007-05-25', '2007-04-25', '2007-03-23', '2007-02-16',
#                '2007-01-16', '2006-12-15', '2006-11-15', '2006-10-13',
#                '2006-09-13', '2006-08-11', '2006-07-11', '2006-06-09',
# ...

# %%
format='%Y-%m-%d %H:%M:%S'
btm = pd.DataFrame(index=index_date,columns=stocks)
i=0
for stk in stocks:
    for date in index_date:
        i=i+1
        if i==1:
            print("type(stk)",type(stk),stk,"type(date)",type(date),date)
            
            dt=date.strftime(format)    
            print("dt",type(dt),dt)
        else:
            pass
        
        
        if hasattr(price_data[stk],dt):
            if price_data[stk][date]!=0:
                btm[stk][date] = df_book_value[stk][date]/price_data[stk][date]
            else:
                btm[stk][date] = 0
        else:
#             print('hasattr error',dt,stk,date,type(date))
            btm[stk][date]=0
            
btm
# Out:
# type(stk) <class 'str'> 002334.XSHE type(date) <class 'pandas.tslib.Timestamp'> 2010-11-01 00:00:00
# dt <class 'str'> 2010-11-01 00:00:00
#            002334.XSHE 000683.XSHE 002326.XSHE 600841.XSHG 000541.XSHE  \
# 2010-11-01           0           0           0           0           0
# 2010-09-30           0           0           0           0           0
# 2010-08-30           0           0           0           0           0
# 2010-07-30           0           0           0           0           0
# 2010-06-30           0           0           0           0           0
# 2010-05-28           0           0           0           0           0
# 2010-04-28           0           0           0           0           0
# 2010-03-26           0           0           0           0           0
# 2010-02-26           0           0           0           0           0
# 2010-01-26           0           0           0           0           0
# ...

# %%
# # datetime.datetime.now().time()
# str='2010-11-01 00:00:00'
# format='%Y-%m-%d %H:%M:%S'
# dt=datetime.datetime.strptime(str,format)
# datetime.datetime(2010, 11, 1, 0, 0)
df
# # dt=datetime.datetime.strptime(str, '%Y-%m-%d %H:%M:%S')
# # isinstance(dt,datetime.datetime)
# tm=time.strptime(str,format)
# tm
# ts=time.mktime(tm)
# ts
# Out:
#            002290.XSHE 600595.XSHG 002378.XSHE
# 2005-11-04         NaN      3.6706         NaN
# 2005-09-30         NaN      3.6175         NaN

# %%
index_date2=df.index
stocks2=df.columns
btm = pd.DataFrame(index=index_date,columns=stocks2)
# print("price_data[stk]",df[stk])
for stk in stocks2:
    for date in index_date2:
#         print("type(stk),type(date)",type(stk),stk,type(date),date)
        dt=date.strftime(format)    
#         print("dt",type(dt),dt)
        
        if hasattr(df[stk],dt):
            if df[stk][date]!=0:
                btm[stk][date] = df_book_value[stk][date]/df[stk][date]
            else:
                btm[stk][date] = 0
        else:
            print('hasattr error',dt,stk,date,type(date))
            
btm
# Out:
# hasattr error 2005-11-04 00:00:00 002290.XSHE 2005-11-04 00:00:00 <class 'pandas.tslib.Timestamp'>
# hasattr error 2005-11-04 00:00:00 600595.XSHG 2005-11-04 00:00:00 <class 'pandas.tslib.Timestamp'>
# hasattr error 2005-11-04 00:00:00 002378.XSHE 2005-11-04 00:00:00 <class 'pandas.tslib.Timestamp'>
#            002290.XSHE 600595.XSHG 002378.XSHE
# 2010-11-01         NaN         NaN         NaN
# 2010-09-30         NaN         NaN         NaN
# 2010-08-30         NaN         NaN         NaN
# 2010-07-30         NaN         NaN         NaN
# 2010-06-30         NaN         NaN         NaN
# 2010-05-28         NaN         NaN         NaN
# 2010-04-28         NaN         NaN         NaN
# 2010-03-26         NaN         NaN         NaN
# 2010-02-26         NaN         NaN         NaN
# 2010-01-26         NaN         NaN         NaN
# 2009-12-25         NaN         NaN         NaN
# 2009-11-25         NaN         NaN         NaN
# 2009-10-23         NaN         NaN         NaN
# ...

# %%
datetime
# Out:
# <module 'datetime' from '/opt/conda/envs/ricequant/lib/python3.5/datetime.py'>

# %%
datetime??

# %%
# %pdb
